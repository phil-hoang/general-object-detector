# %% [markdown]
# # Logs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
logs = pickle.load(open("logfile.log", "rb"))

# %%
print(logs.keys())
print(len(logs['min_conf']))
# Out:
# dict_keys(['fps', 'inference_time', 'num_objects', 'min_conf'])
# 160

# %%
plt.plot(logs["inference_time"])
